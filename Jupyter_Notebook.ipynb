# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Waston Studio

# %% [markdown]
# **Chisomaga Opara-Nestor**
# Data analyst

# %% [markdown]
# *Most professions now are hinging on data science to still be relevant in the future. Therefore I am interested in data science to still maintain relevance in the future in my chosen profession.*

# %% [markdown]
# ### The code in the cell below would declear three variables and test if a combination of any two of such variables is equal to the third ###

# %%
a = 5
b = 7
c = 12
c == a + b
# Out:
# True

# %% [markdown]
# ***
# - Data science
# - IBM skills Network
# - Learning
#
# 1. Super computer
# 1. Big data
# 1. Exploring
#
#
# ![th-1292649126.jpg](attachment:82bd3dd5-861f-4d28-8ca3-5afd5289504c.jpg)
